# %%
import pandas as pd 

data = pd.read_csv("sales_data.csv")

data[data['Product Category'] == 'Electronics']
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 6             10007  2024-01-07      Electronics
# 12            10013  2024-01-13      Electronics
# 18            10019  2024-01-19      Electronics
# 24            10025  2024-01-25      Electronics
# 30            10031  2024-01-31      Electronics
# 36            10037  2024-02-06      Electronics
# 42            10043  2024-02-12      Electronics
# 48            10049  2024-02-18      Electronics
# 54            10055  2024-02-24      Electronics
# 60            10061  2024-03-01      Electronics
# 66            10067  2024-03-07      Electronics
# 72            10073  2024-03-13      Electronics
# 78            10079  2024-03-19      Electronics
# 84            10085  2024-03-25      Electronics
# 90            10091  2024-03-31      Electronics
# 96            10097  2024-04-06      Electronics
# 102           10103  2024-04-12      Electronics
# ...

# %%
data.groupby(['Product Category', 'Region'])['Units Sold'].sum()
# Out:
# Product Category  Region
# Beauty Products   Europe            46
# Books             North America    114
# Clothing          Asia             145
# Electronics       North America     66
# Home Appliances   Europe            59
# Sports            Asia              88
# Name: Units Sold, dtype: int64
